# %%
a=2

# %%
a/2
# Out:
# 1.0

# %%
a**2
# Out:
# 4

# %%
b=" phyton "

# %%
b*2
# Out:
# 'phytonphyton'

# %%
c="Geovy"

# %%
b+c
# Out:
# ' phyton Geovy'

# %%
b*4
# Out:
# ' phyton  phyton  phyton  phyton '

# %%
lista_1=[1,2,3,4,5]

# %%
lista_1
# Out:
# [1, 2, 3, 4, 5]

# %%
lista_1[-5]
# Out:
# 1

# %%
len(lista_1)
# Out:
# 5

# %%
print(lista_1)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(c)
# Out:
# Geovy

# %%
print ("los valores de la lista es:",lista_1)
# Out:
# los valores de la lista es: [1, 2, 3, 4, 5]

# %%
from PIL import Image

# %%
imagen=Image.open ("juegos olimpicos.JPG")

# %%
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=799x449 at 0x21B7874C280>

# %%
import pandas as pd

# %%
#lectura de archivos panda es para data frame

# %%
data_excel=pd.read_excel("Data.xlsx",sheet_name="Hoja1")

# %%
data_excel
# Out:
#   LETRAS  NUMEROS
# 0      A        1
# 1      B        2
# 2      C        3
# 3      D        4
# 4      E        5
# 5      F        6
# 6      G        7
# 7      H        8
# 8      I        9
# 9      J       10

# %%
data_excel["CALCULO"]=data_excel.NUMEROS*3

# %%
data_excel
# Out:
#   LETRAS  NUMEROS  CALCULO
# 0      A        1        3
# 1      B        2        6
# 2      C        3        9
# 3      D        4       12
# 4      E        5       15
# 5      F        6       18
# 6      G        7       21
# 7      H        8       24
# 8      I        9       27
# 9      J       10       30

# %%
import altair as alt

# %%
grafico=alt.Chart(data_excel).mark_line().encode(
    x="NUMEROS",
    y="CALCULO",
    tooltip=["NUMEROS","CALCULO"]).interactive()

# %%
grafico.display()
# Out:
# alt.Chart(...)
